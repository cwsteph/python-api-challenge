# %% [markdown]
# # WeatherPy
# ----
#
# #### Observed Trend 1)
#
# #### Observed Trend 2)
#
# #### Observed Trend 3)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from citipy import citipy
import time
from api_keys import api_key

# Import API key


# Incorporated citipy to determine city based on latitude and longitude


# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#len(cities)

pprint(cities)
# Out:
# ['bredasdorp',
#  'port elizabeth',
#  'albany',
#  'clyde river',
#  'wamba',
#  'vostok',
#  'praia da vitoria',
#  'east london',
#  'punta arenas',
#  'seoul',
#  'halalo',
#  'grand centre',
#  'rikitea',
#  'georgetown',
#  'kapaa',
#  'kaeo',
#  'talnakh',
#  'palabuhanratu',
#  'ushuaia',
#  'henties bay',
#  'santo antonio do sudoeste',
#  'okha',
#  'suluq',
#  'broome',
#  'shimoda',
#  'taolanaro',
#  'nkhata bay',
#  'ribeira grande',
#  'mamallapuram',
#  'sitka',
#  'hermanus',
#  'vaini',
#  'vestmannaeyjar',
#  'constitucion',
#  'waw',
#  'busselton',
#  'saint george',
#  'illoqqortoormiut',
#  'abdanan',
#  'williamsburg',
#  'hambantota',
#  'new norfolk',
#  'tautira',
#  'mataura',
#  'sur',
#  'hobart',
#  'markdale',
#  'plettenberg bay',
#  'tapaua',
#  'tabou',
#  'atuona',
#  'yenagoa',
#  'vao',
#  'binga',
#  'port hardy',
#  'lagoa',
#  'mahebourg',
#  'surgut',
#  'vitim',
#  'temaraia',
#  'vardo',
#  'chuy',
#  'hilo',
#  'kodiak',
#  'attawapiskat',
#  'auki',
#  'calama',
#  'bethel',
#  'yulara',
#  'komsomolskiy',
#  'provideniya',
#  'assisi',
#  'casa nova',
#  'tabuk',
#  'ancud',
#  'qaqortoq',
#  'airai',
#  'san cristobal',
#  'buala',
#  'castro',
#  'brandon',
#  'bela',
#  'cape town',
#  'sorland',
#  'jamestown',
#  'okhotsk',
#  'agadez',
#  'dingle',
#  'petropavlovsk-kamchatskiy',
#  'dudinka',
#  'port alfred',
#  'moose factory',
#  'mar del plata',
#  'hobyo',
#  'saurimo',
#  'delmiro gouveia',
#  'pisco',
#  'todos santos',
#  'chapais',
#  'kununurra',
#  'belushya guba',
#  'ust-shonosha',
#  'iqaluit',
#  'manta',
#  'lamlash',
#  'alofi',
#  'severo-kurilsk',
#  'ponta do sol',
#  'meulaboh',
#  'oktyabrskoye',
#  'sarlat-la-caneda',
#  'nalut',
#  'arraial do cabo',
#  'tottori',
#  'butaritari',
#  'tombouctou',
#  'beloha',
#  'ambovombe',
#  'chebsara',
#  'yangambi',
#  'thompson',
#  'upernavik',
#  'sayyan',
#  'bluff',
#  'hithadhoo',
#  'crestview',
#  'mys shmidta',
#  'avarua',
#  'saint-augustin',
#  'paita',
#  'carnarvon',
#  'bubaque',
#  'jojoima',
#  'olinda',
#  'haines junction',
#  'tasiilaq',
#  'tuktoyaktuk',
#  'kaitangata',
#  'hasaki',
#  'puerto ayora',
#  'nizhneyansk',
#  'ambon',
#  'srednekolymsk',
#  'miandrivazo',
#  'sao jose da coroa grande',
#  'vila velha',
#  'yumen',
#  'leningradskiy',
#  'the pas',
#  'amderma',
#  'berlevag',
#  'patan',
#  'sola',
#  'maridi',
#  'ternate',
#  'grand river south east',
#  'aktau',
#  'tumpat',
#  'lompoc',
#  'nikolskoye',
#  'saint anthony',
#  'chernyshevskiy',
#  'marcona',
#  'sosva',
#  'evensk',
#  'lusambo',
#  'sarangani',
#  'dunedin',
#  'cidreira',
#  'guerrero negro',
#  'terra santa',
#  'qaanaaq',
#  'qasigiannguit',
#  'camamu',
#  'saldanha',
#  'carutapera',
#  'muros',
#  'osypenko',
#  'souillac',
#  'ituni',
#  'luderitz',
#  'naze',
#  'padang',
#  'dikson',
#  'nouadhibou',
#  'shahr-e kord',
#  'tessalit',
#  'coihaique',
#  'deogarh',
#  'saint-philippe',
#  'yeppoon',
#  'tall kayf',
#  'yellowknife',
#  'kharan',
#  'lensk',
#  'barrow',
#  'bradford',
#  'hamilton',
#  'port hedland',
#  'narsaq',
#  'dutse',
#  'norman wells',
#  'aksarka',
#  'pevek',
#  'port blair',
#  'umm kaddadah',
#  'eyrarbakki',
#  'cocachacra',
#  'bambanglipuro',
#  'orlik',
#  'deputatskiy',
#  'thornaby',
#  'mount isa',
#  'tiksi',
#  'kalulushi',
#  'toliary',
#  'uvalde',
#  'takoradi',
#  'sao filipe',
#  'tazovskiy',
#  'ridgecrest',
#  'uhlove',
#  'sterling',
#  'benguela',
#  'cockburn town',
#  'impfondo',
#  'turkistan',
#  'cherskiy',
#  'klaksvik',
#  'surin',
#  'banda aceh',
#  'barcelos',
#  'po',
#  'safaga',
#  'mananjary',
#  'mnogovershinnyy',
#  'moroto',
#  'chokurdakh',
#  'saleaula',
#  'ostrovnoy',
#  'hays',
#  'aswan',
#  'winburg',
#  'faya',
#  'lumban',
#  'fortuna foothills',
#  'tokur',
#  'arnedo',
#  'pemberton',
#  'yingcheng',
#  'shakhtinsk',
#  'san jeronimo',
#  'nabire',
#  'jaru',
#  'gushikawa',
#  'arlit',
#  'alghero',
#  'nantucket',
#  'maldonado',
#  'tuatapere',
#  'teya',
#  'nanortalik',
#  'mehamn',
#  'ahuimanu',
#  'angoche',
#  'sudak',
#  'matehuala',
#  'yamada',
#  'bajos de haina',
#  'adrar',
#  'vila franca do campo',
#  'yarada',
#  'port augusta',
#  'teguise',
#  'khatanga',
#  'roald',
#  'torbay',
#  'kavieng',
#  'mezen',
#  'dumai',
#  'giyani',
#  'bambous virieux',
#  'ust-tsilma',
#  'longyearbyen',
#  'bridlington',
#  'riberalta',
#  'wanning',
#  'little current',
#  'dunkirk',
#  'berbera',
#  'evenskjaer',
#  'colwyn bay',
#  'half moon bay',
#  'westpunt',
#  'timra',
#  'miyazu',
#  'lebanon',
#  'vuktyl',
#  'aklavik',
#  'rocha',
#  'sinkat',
#  'vaitupu',
#  'santa maria',
#  'bengkulu',
#  'barentsburg',
#  'linqing',
#  'karauzyak',
#  'machilipatnam',
#  'cabo san lucas',
#  'tooele',
#  'batagay-alyta',
#  'kagadi',
#  'faanui',
#  'ihosy',
#  'puerto carreno',
#  'nago',
#  'biu',
#  'rorvik',
#  'broken hill',
#  'olafsvik',
#  'ipixuna',
#  'kruisfontein',
#  'umzimvubu',
#  'isakly',
#  'kuche',
#  'farah',
#  'tsihombe',
#  'lata',
#  'shingu',
#  'camopi',
#  'staryy nadym',
#  'tura',
#  'baruun-urt',
#  'tangier',
#  'portland',
#  'kieta',
#  'katsuura',
#  'wukari',
#  'goundam',
#  'nyimba',
#  'ballsh',
#  'jalu',
#  'the valley',
#  'itoman',
#  'hammerfest',
#  'pangnirtung',
#  'fort saint james',
#  'rungata',
#  'vikramasingapuram',
#  'sept-iles',
#  'pauini',
#  'porto uniao',
#  'grand gaube',
#  'la tuque',
#  'ketchikan',
#  'calbuco',
#  'niksar',
#  'coahuayana',
#  'bandundu',
#  'kumano',
#  'hofn',
#  'buchanan',
#  'fairbanks',
#  'galle',
#  'paamiut',
#  'camacha',
#  'ramkola',
#  'mitu',
#  'quatre cocos',
#  'novooleksiyivka',
#  'odweyne',
#  'terney',
#  'haapiti',
#  'homer',
#  'lebu',
#  'nelson bay',
#  'rudbar',
#  'saskylakh',
#  'tezu',
#  'chulym',
#  'aksu',
#  'esperance',
#  'prince rupert',
#  'acapulco',
#  'banjar',
#  'kautokeino',
#  'cocorit',
#  'nuevo progreso',
#  'perth',
#  'yala',
#  'tahta',
#  'kavaratti',
#  'gat',
#  'kirkkonummi',
#  'waddan',
#  'ballina',
#  'oyem',
#  'puerto colombia',
#  'bahia blanca',
#  'senno',
#  'beringovskiy',
#  'ilulissat',
#  'kyzyl-suu',
#  'samusu',
#  'octeville',
#  'flin flon',
#  'taburi',
#  'baie-comeau',
#  'pandan',
#  'caucaia',
#  'nome',
#  'izhma',
#  'kamenskoye',
#  'bonavista',
#  'sindand',
#  'vanimo',
#  'cefalu',
#  'talaya',
#  'poso',
#  'grao mogol',
#  'bengbu',
#  'umm ruwabah',
#  'mongo',
#  'loukhi',
#  'bolu',
#  'lagoa santa',
#  'geraldton',
#  'mae hong son',
#  'muisne',
#  'cascais',
#  'bolsheustikinskoye',
#  'atar',
#  'abnub',
#  'vrangel',
#  'mayo',
#  'bairiki',
#  'mrirt',
#  'salta',
#  'byron bay',
#  'karakendzha',
#  'santa rosa',
#  'ahipara',
#  'penne',
#  'lucapa',
#  'qandahar',
#  'krasnoselkup',
#  'blagoevgrad',
#  'kandrian',
#  'minggang',
#  'fortuna',
#  'syriam',
#  'kemijarvi',
#  'west bay',
#  'namibe',
#  'pozo colorado',
#  'whitecourt',
#  'linqiong',
#  'moerai',
#  'la asuncion',
#  'kolondieba',
#  'pangai',
#  'pascagoula',
#  'chagda',
#  'college',
#  'ekibastuz',
#  'salalah',
#  'touros',
#  'general pico',
#  'yigou',
#  'aripuana',
#  'la primavera',
#  'villa carlos paz',
#  'tevaitoa',
#  'walvis bay',
#  'pijijiapan',
#  'khonsa',
#  'necochea',
#  'bagdarin',
#  'ormara',
#  'anadyr',
#  'thinadhoo',
#  'yanam',
#  'burica',
#  'ruatoria',
#  'codrington',
#  'moron',
#  'empalme',
#  'ulundi',
#  'mirabad',
#  'san policarpo',
#  'aquiraz',
#  'cacoal',
#  'noumea',
#  'nguiu',
#  'utiroa',
#  'rio gallegos',
#  'meiganga',
#  'mweka',
#  'palenque',
#  'te anau',
#  'smithers',
#  'gallup',
#  'galbshtadt',
#  'ljungby',
#  'inhambane',
#  'borogontsy',
#  'bathsheba',
#  'trat',
#  'mwanza',
#  'boa vista',
#  'dalby',
#  'slave lake',
#  'laguna de perlas',
#  'batsfjord',
#  'dalbandin',
#  'ellisras',
#  'kulhudhuffushi',
#  'maceio',
#  'kahului',
#  'lorengau',
#  'bowen',
#  'assai',
#  'pierre',
#  'xai-xai',
#  'sao joao da barra',
#  'jilmah',
#  'grindavik',
#  'balaipungut',
#  'libreville',
#  'sri aman',
#  'kysyl-syr',
#  'saqqez',
#  'daru',
#  'majene',
#  'cruden bay',
#  'victoria',
#  'manokwari',
#  'abha',
#  'itarema',
#  'oshawa',
#  'shatki',
#  'pahrump',
#  'kudahuvadhoo',
#  'chipinge',
#  'kovdor',
#  'harnosand',
#  'bull savanna',
#  'amapa',
#  'vallenar',
#  'akyab',
#  'warri',
#  'skalistyy',
#  'akdepe',
#  'saint-pierre',
#  'gollere',
#  'viedma',
#  'zhigansk',
#  'bandarbeyla',
#  'fond du lac',
#  'vandra',
#  'montague',
#  'denpasar',
#  'margate',
#  'lavrentiya',
#  'lovozero',
#  'puerto del rosario',
#  'tommot',
#  'tecoanapa',
#  'mogapi',
#  'pacific grove',
#  'pontes e lacerda',
#  'kytlym',
#  'lodja',
#  'egvekinot',
#  'sioni',
#  'port macquarie',
#  'vidim',
#  'zalantun',
#  'payakumbuh',
#  'sinnamary',
#  'nouakchott',
#  'vizinga',
#  'san patricio',
#  'la colorada',
#  'huarmey',
#  'chenzhou',
#  'kadaya',
#  'sibolga',
#  'pochutla',
#  'harper',
#  'stromness',
#  'mount gambier',
#  'dhidhdhoo',
#  'churapcha',
#  'cayenne']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
#
#
#
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
country = []
city_list = []
latitude = []
longitude = []
humidity = []
cloudiness = []
wind_speed = []
max_temp = []


url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{url}appid={api_key}&units=imperial&q="

# %%
count = 0 

for city in cities:
    count += 1
    print(city + ': ' + str(count))
    try:
        time.sleep(1)
        response = requests.get(f"{query_url}{city}").json()
        country.append(response['sys']['country'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
# kytlym: 572
# That city doesn't exist-Skipping
# lodja: 573
# egvekinot: 574
# sioni: 575
# port macquarie: 576
# vidim: 577
# zalantun: 578
# payakumbuh: 579
# sinnamary: 580
# nouakchott: 581
# vizinga: 582
# san patricio: 583
# la colorada: 584
# huarmey: 585
# chenzhou: 586
# kadaya: 587
# sibolga: 588
# pochutla: 589
# harper: 590
# stromness: 591
# mount gambier: 592
# dhidhdhoo: 593
# churapcha: 594
# cayenne: 595

# %%
weather_df
print(weather_df)
# Out:
#     country    lat     lon  humidity  cloudiness  wind speed  max temp  \
# 0        ZA -34.53   20.04        82         100       12.75     64.40
# 1        ZA -33.92   25.57        82          90       21.92     64.40
# 2        US  42.60  -73.97        82         100        5.86     48.00
# 3        CA  70.47  -68.59        72          90       16.11     14.00
# 4        NG   8.93    8.60        60          46        0.67     76.93
# ..      ...    ...     ...       ...         ...         ...       ...
# 543      GB  58.97   -3.30        87          75       10.22     48.20
# 544      AU -37.83  140.77        87         100       11.41     46.40
# 545      MV   6.88   73.10        73           2        6.08     82.49
# 546      RU  62.00  132.43        91         100        4.52     13.66
# 547      GF   4.93  -52.33        62          18       14.99     87.80
#
#                city
# 0        bredasdorp
# 1    port elizabeth
# 2            albany
# 3       clyde river
# 4             wamba
# ..              ...
# 543       stromness
# 544   mount gambier
# 545       dhidhdhoo
# 546       churapcha
# 547         cayenne
#
# [548 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.to_csv(output_data_file)

# %%
weather_df.describe()
# Out:
#               lat         lon    humidity  cloudiness  wind speed    max temp
# count  548.000000  548.000000  548.000000  548.000000  548.000000  548.000000
# mean    19.410328   16.174380   71.978102   53.720803    8.143650   60.150091
# std     33.498861   90.078703   22.509057   40.830910    5.724584   22.728395
# min    -54.800000 -179.170000    5.000000    0.000000    0.400000   -1.320000
# 25%     -8.152500  -60.865000   62.000000    4.750000    3.890000   46.320000
# 50%     20.510000   22.305000   79.000000   72.000000    6.930000   66.200000
# 75%     47.752500   95.382500   88.000000   96.250000   11.410000   78.287500
# max     78.220000  179.320000  100.000000  100.000000   32.820000   99.590000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ## Skipping, none over 100%

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['lat'],weather_df['max temp'])

plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Latitude vs. Temperature')
plt.savefig('templat.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['lat'],weather_df['humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs. Humidity')
plt.savefig('lathumid.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['lat'],weather_df['cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs. Cloudiness')
plt.savefig('latcloud.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['lat'],weather_df['wind speed'])

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs. Wind Speed')
plt.savefig('latspeed.png')

# %% [markdown]
# ## Linear Regression

# %%
northern_df = weather_df.loc[weather_df['lat']>0]
southern_df = weather_df.loc[weather_df['lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df['lat']
y_values = northern_df['max temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df['lat']
y_values = southern_df['max temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['lat']
y_values = northern_df['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['lat']
y_values = southern_df['humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['lat']
y_values = northern_df['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['lat']
y_values = southern_df['cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['lat']
y_values = northern_df['wind speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['lat']
y_values = southern_df['wind speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
